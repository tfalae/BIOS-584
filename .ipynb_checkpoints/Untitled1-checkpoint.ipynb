# %%
pip install pyreadstat
# Out:
# ...
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------  2.4/2.4 MB 16.1 MB/s eta 0:00:01
#    ---------------------------------------  2.4/2.4 MB 16.1 MB/s eta 0:00:01
#    ---------------------------------------  2.4/2.4 MB 16.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 2.9 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
# ...

# %%
import pyreadstat

df, meta = pyreadstat.read_sav("Obesity.sav")
print(df.head())
# Out:
#    Gender   Age  Race  Marital_status  Education  Occupation  \
# 0     2.0  64.0   3.0             1.0        3.0         2.0
# 1     1.0  59.0   1.0             2.0        3.0         2.0
# 2     2.0  41.0   3.0             2.0        3.0         7.0
# 3     2.0  21.0   2.0             1.0        3.0         2.0
# 4     2.0  68.0   3.0             2.0        2.0         6.0
#
#    Household_income  Weight  Height    WC  ...  Nutrition_Fruits  Vege_scale  \
# 0            3000.0   68.70   160.0  43.0  ...               2.0         7.0
# 1            2000.0   80.45   160.0  56.0  ...               3.0         4.0
# 2            2000.0   52.25   155.0  69.0  ...               4.0         7.0
# 3            2500.0   41.00   148.0  70.0  ...               1.0         1.0
# 4            1500.0   42.61   148.0  70.0  ...               7.0         7.0
#
#    Nutrition_Veggies        BMI  BMI_WHO  BMI_CPG  BMI_2cat  BMI_2cat_WHO  \
# ...
